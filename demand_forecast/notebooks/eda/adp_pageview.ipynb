# %%
adp_page_view_df = spark.table('production.events.cleaned__activityview')

# %%
adp_page_view_df.count()
# Out:
# ...
# 1680929398

# %%
tour_events_df = (
    adp_page_view_df
    .filter(F.col('tour_id') == 478687)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 tour_events_df = (
#       2     adp_page_view_df
# ----> 3     .filter(F.col('tour_id') == 478687)
#       4 )
#
# NameError: name 'F' is not defined

# %%
from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.sql.types import StringType
from pyspark.sql import Window
import pandas as pd
import numpy as np

# %%
spark

# %%
df = spark.table('production.dwh.fact_booking')

# %%
df.printSchema()
# Out:
# root
#  |-- date_of_checkout: timestamp (nullable = true)
#  |-- booking_id: long (nullable = true)
#  |-- shopping_cart_id: long (nullable = true)
#  |-- tour_id: long (nullable = true)
#  |-- tour_option_id: long (nullable = true)
#  |-- location_id: long (nullable = true)
#  |-- status_id: integer (nullable = true)
#  |-- master_language_id: long (nullable = true)
#  |-- customer_id_anon: string (nullable = true)
#  |-- customer_address_id_anon: string (nullable = true)
#  |-- customer_address_lead_traveller_id_anon: string (nullable = true)
#  |-- customer_country_id: long (nullable = true)
#  |-- customer_language_id: long (nullable = true)
#  |-- customer_currency_id: long (nullable = true)
#  |-- device_id: integer (nullable = true)
#  |-- visitor_id: string (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- token: string (nullable = true)
#  |-- hash_code: string (nullable = true)
#  |-- supplier_id: long (nullable = true)
#  |-- supplier_currency_id: long (nullable = true)
#  |-- reseller_id: long (nullable = true)
#  |-- reseller_currency_id: long (nullable = true)
#  |-- reseller_source_id: long (nullable = true)
#  |-- reseller_payment_id: long (nullable = true)
#  |-- reseller_reference_code: string (nullable = true)
#  |-- api_credential_id: long (nullable = true)
#  |-- gyg_campaign_id: long (nullable = true)
#  |-- deal_id: long (nullable = true)
#  |-- option_language_id: long (nullable = true)
#  |-- locale_id: long (nullable = true)
#  |-- is_customer_logged_in: boolean (nullable = true)
#  |-- is_mobile: boolean (nullable = true)
#  |-- is_fraud: boolean (nullable = true)
#  |-- confirmation_user_id: long (nullable = true)
#  |-- assigned_staff_id: long (nullable = true)
#  |-- date_of_checkout_local: timestamp (nullable = true)
#  |-- date_of_creation: timestamp (nullable = true)
#  |-- date_of_confirmation: timestamp (nullable = true)
#  |-- date_of_cancelation: timestamp (nullable = true)
#  |-- date_of_travel: timestamp (nullable = true)
#  |-- date_of_travel_utc: long (nullable = true)
#  |-- date_of_travel_type: string (nullable = true)
#  |-- date_of_travel_utc_original: long (nullable = true)
#  |-- all_travel_dates_utc: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- gmv_customer_local_currency: decimal(17,2) (nullable = true)
#  |-- gmv_supplier_local_currency: decimal(17,2) (nullable = true)
#  |-- gmv_reseller_local_currency: decimal(17,2) (nullable = true)
#  |-- supplier_share_local_currency: decimal(13,2) (nullable = true)
#  |-- reseller_share_local_currency: decimal(13,2) (nullable = true)
#  |-- commission_rate: decimal(9,3) (nullable = true)
#  |-- commission_rate_reseller: decimal(9,3) (nullable = true)
#  |-- commission_rate_reseller_gyg_transaction: decimal(9,3) (nullable = true)
#  |-- tickets: long (nullable = true)
#  |-- deal_tickets: long (nullable = true)
#  |-- mwst: boolean (nullable = true)
#  |-- billing_details: string (nullable = true)
#  |-- modification_log: string (nullable = true)
#  |-- review_num_of_reminders_sent: long (nullable = true)
#  |-- accounting_transaction_logged_travel: boolean (nullable = true)
#  |-- supplier_contact: boolean (nullable = true)
#  |-- support_email: boolean (nullable = true)
#  |-- support_phone: boolean (nullable = true)
#  |-- redemption_timestamp: timestamp (nullable = true)
#  |-- reservation_expiry_timestamp: timestamp (nullable = true)
#  |-- update_timestamp: timestamp (nullable = true)
#  |-- update_user_id: long (nullable = true)
#  |-- cycle_timestamp: timestamp (nullable = true)
#  |-- billing_details_first: string (nullable = true)
#  |-- reseller_visitor_id: string (nullable = true)
#  |-- has_third_party_booking_voucher: boolean (nullable = true)
#  |-- guide_status_id: integer (nullable = true)
#  |-- booking_type_id: integer (nullable = true)
#  |-- reseller_type_id: integer (nullable = true)
#  |-- reseller_campaign_id: integer (nullable = true)
#  |-- reseller_revenue_model_id: integer (nullable = true)
#  |-- update_user_type_id: integer (nullable = true)
#  |-- confirmation_user_type_id: integer (nullable = true)
#  |-- attribution_id: integer (nullable = true)
#  |-- exchange_rate_eur_customer: decimal(24,8) (nullable = true)
#  |-- exchange_rate_eur_supplier: decimal(24,8) (nullable = true)
#  |-- exchange_rate_eur_reseller: decimal(24,8) (nullable = true)
#  |-- gmv: decimal(17,2) (nullable = true)
#  |-- gmv_total: decimal(17,2) (nullable = true)
#  |-- gmv_total_active: decimal(17,2) (nullable = true)
#  |-- gmv_supplier: decimal(17,2) (nullable = true)
#  |-- supplier_share: decimal(17,2) (nullable = true)
#  |-- gmv_reseller: decimal(17,2) (nullable = true)
#  |-- reseller_share: decimal(17,2) (nullable = true)
#  |-- nr_supplier_share: decimal(17,2) (nullable = true)
#  |-- nr: decimal(17,2) (nullable = true)
#  |-- checkout_booking_engine: string (nullable = true)
#  |-- selling_tax_eur: double (nullable = true)
#  |-- net_tax_eur: decimal(17,2) (nullable = true)
#  |-- total_tax: decimal(17,2) (nullable = true)
#  |-- tax_pcnt_sale: decimal(17,4) (nullable = true)
#  |-- tax_pcnt_purchase: decimal(17,4) (nullable = true)
#  |-- price_net_rate_eur: decimal(38,18) (nullable = true)
#  |-- risk_premium: decimal(38,18) (nullable = true)
#  |-- transaction_weight: decimal(38,18) (nullable = true)
#  |-- extra_gyg_share: double (nullable = true)
#  |-- extra_gyg_share_eur: double (nullable = true)
#  |-- virtual_activity_id: long (nullable = true)
#  |-- device_category_id: integer (nullable = true)
#  |-- booking_reference: string (nullable = true)
#  |-- first_trip_booking: integer (nullable = true)
#  |-- borders: string (nullable = true)
#  |-- connector_status: string (nullable = true)
#  |-- connector_failure_reason: string (nullable = true)
#  |-- supplier_invoice_id: long (nullable = true)

# %%
print(f"Row count: {df.count():,}")
# Out:
# Row count: 132,222,377
